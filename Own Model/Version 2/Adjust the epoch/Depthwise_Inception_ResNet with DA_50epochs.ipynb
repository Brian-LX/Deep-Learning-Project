# %%
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow import keras
import keras.backend as K
import tensorflow as tf
import pandas as pd

# %%
train_dir = r'data/RiceLeafsDisease/train/'
test_dir = r'data/RiceLeafsDisease/validation/'

val_loss = list()
val_accuracy = list()
test_loss= list()
test_accuracy = list()

# %%
BATCH_SIZE = 32
seeds = 41
im_shape = (250,250)

# %%
# Load and preprocess the training data
train_generator = ImageDataGenerator(rescale=1./255, rotation_range=40,shear_range=0.2, zoom_range=0.2,width_shift_range=0.2,horizontal_flip=True,validation_split=0.2)
val_data_generator = ImageDataGenerator(rescale=1./255, rotation_range=40,shear_range=0.2, zoom_range=0.2,width_shift_range=0.2,horizontal_flip=True,validation_split=0.2)
test_generator = ImageDataGenerator(rescale=1./255, rotation_range=40,shear_range=0.2, zoom_range=0.2,width_shift_range=0.2,horizontal_flip=True)

# Generator of Train
train_generator = train_generator.flow_from_directory(train_dir, target_size=im_shape, shuffle=True, seed=seeds,
                                                     class_mode='categorical',color_mode='rgb', batch_size=BATCH_SIZE, subset="training")
# Generator of validation
validation_generator = val_data_generator.flow_from_directory(train_dir, target_size=im_shape, shuffle=False, seed=seeds,
                                                     class_mode='categorical',color_mode='rgb', batch_size=BATCH_SIZE, subset="validation")

# Generator of dataset test
test_generator = test_generator.flow_from_directory(test_dir, target_size=im_shape, shuffle=False, seed=seeds,
                                                     class_mode='categorical',color_mode='rgb', batch_size=BATCH_SIZE)

nb_train_samples = train_generator.samples
nb_validation_samples = validation_generator.samples
nb_test_samples = test_generator.samples
classes = list(train_generator.class_indices.keys())
print('Classes: '+str(classes))
num_classes  = len(classes)
# Out:
# Found 1680 images belonging to 6 classes.
# Found 420 images belonging to 6 classes.
# Found 528 images belonging to 6 classes.
# Classes: ['bacterial_leaf_blight', 'brown_spot', 'healthy', 'leaf_blast', 'leaf_scald', 'narrow_brown_spot']

# %% [markdown]
# # InceptionResNet Model

# %%
from keras.layers import Input, Conv2D, DepthwiseConv2D, Concatenate, Add, AveragePooling2D, Flatten, Dense, Dropout

def inception_module(x, filters):
    # Branch 1:1 x1 convolution
    branch_1x1 = Conv2D(filters=filters[0], kernel_size=(1, 1), strides=1, padding='same', activation='relu')(x)

    # Branch 2: depth-separable convolution (3x3)
    branch_3x3 = DepthwiseConv2D(kernel_size=(3, 3), strides=1, padding='same', activation='relu')(x)
    branch_3x3 = Conv2D(filters=filters[1], kernel_size=(1, 1), strides=1, padding='same', activation='relu')(branch_3x3)

    # Branch 3: Depth-separable Convolution (5x5)
    branch_5x5 = DepthwiseConv2D(kernel_size=(5, 5), strides=1, padding='same', activation='relu')(x)
    branch_5x5 = Conv2D(filters=filters[2], kernel_size=(1, 1), strides=1, padding='same', activation='relu')(branch_5x5)

    # The branch 4:3x3 is maximized and then convolved with 1x1
    branch_pool = AveragePooling2D(pool_size=(3, 3), strides=1, padding='same')(x)
    branch_pool = Conv2D(filters=filters[3], kernel_size=(1, 1), strides=1, padding='same', activation='relu')(branch_pool)

    output = Concatenate(axis=-1)([branch_1x1, branch_3x3, branch_5x5, branch_pool])
    return output

def residual_block(x, filters):
    # Save the input for subsequent residual connections
    shortcut = x

    # The first Inception module
    x = inception_module(x, filters)

    # The Second Inception module
    x = inception_module(x, filters)

    # If the input and output dimensions do not match, the dimensions are adjusted using 1x1 convolution
    if shortcut.shape[-1] != x.shape[-1]:
        shortcut = Conv2D(filters=x.shape[-1], kernel_size=(1, 1), strides=1, padding='same')(shortcut)

    # Residual connection
    x = Add()([shortcut, x])
    x = tf.keras.layers.Activation('relu')(x)
    return x

# Input Layer
input_layer = Input(shape=(250, 250, 3))

# Convolution layer
conv1 = Conv2D(64, (5, 5), strides=(2, 2), padding='same', activation='relu')(input_layer)

# Residual block
res_block1 = residual_block(conv1, [32, 64, 128, 32])
res_block2 = residual_block(res_block1, [64, 64, 128, 32])

# Average pooling layer
pool2 = AveragePooling2D(pool_size=(4, 4))(res_block2)

# Fully connected layer
flatten = Flatten()(pool2)
output_layer = Dense(6, activation='softmax')(flatten)

model = Model(inputs=input_layer, outputs=output_layer)
# Out:
# 2024-04-16 19:24:53.842828: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-16 19:24:53.982722: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-16 19:24:53.983198: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-16 19:24:53.985520: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-16 19:24:53.985841: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-16 19:24:53.986093: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-16 19:24:56.476899: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-16 19:24:56.477214: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-16 19:24:56.477437: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-16 19:24:56.477578: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-04-16 19:24:56.477668: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14226 MB memory:  -> device: 0, name: NVIDIA RTX A4000, pci bus id: 0000:10:00.0, compute capability: 8.6

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 250, 250, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 125, 125, 64)         4864      ['input_1[0][0]']
#
#  depthwise_conv2d (Depthwis  (None, 125, 125, 64)         640       ['conv2d[0][0]']
#  eConv2D)
#
#  depthwise_conv2d_1 (Depthw  (None, 125, 125, 64)         1664      ['conv2d[0][0]']
#  iseConv2D)
#
#  average_pooling2d (Average  (None, 125, 125, 64)         0         ['conv2d[0][0]']
#  Pooling2D)
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)         2080      ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 125, 125, 64)         4160      ['depthwise_conv2d[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 125, 125, 128)        8320      ['depthwise_conv2d_1[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 125, 125, 32)         2080      ['average_pooling2d[0][0]']
#
#  concatenate (Concatenate)   (None, 125, 125, 256)        0         ['conv2d_1[0][0]',
#                                                                      'conv2d_2[0][0]',
#                                                                      'conv2d_3[0][0]',
#                                                                      'conv2d_4[0][0]']
#
#  depthwise_conv2d_2 (Depthw  (None, 125, 125, 256)        2560      ['concatenate[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_3 (Depthw  (None, 125, 125, 256)        6656      ['concatenate[0][0]']
#  iseConv2D)
#
#  average_pooling2d_1 (Avera  (None, 125, 125, 256)        0         ['concatenate[0][0]']
#  gePooling2D)
#
#  conv2d_5 (Conv2D)           (None, 125, 125, 32)         8224      ['concatenate[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 125, 125, 64)         16448     ['depthwise_conv2d_2[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 125, 125, 128)        32896     ['depthwise_conv2d_3[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 125, 125, 32)         8224      ['average_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 125, 125, 256)        16640     ['conv2d[0][0]']
#
#  concatenate_1 (Concatenate  (None, 125, 125, 256)        0         ['conv2d_5[0][0]',
#  )                                                                   'conv2d_6[0][0]',
#                                                                      'conv2d_7[0][0]',
#                                                                      'conv2d_8[0][0]']
#
#  add (Add)                   (None, 125, 125, 256)        0         ['conv2d_9[0][0]',
#                                                                      'concatenate_1[0][0]']
#
#  activation (Activation)     (None, 125, 125, 256)        0         ['add[0][0]']
#
#  depthwise_conv2d_4 (Depthw  (None, 125, 125, 256)        2560      ['activation[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_5 (Depthw  (None, 125, 125, 256)        6656      ['activation[0][0]']
#  iseConv2D)
#
#  average_pooling2d_2 (Avera  (None, 125, 125, 256)        0         ['activation[0][0]']
#  gePooling2D)
#
#  conv2d_10 (Conv2D)          (None, 125, 125, 64)         16448     ['activation[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 125, 125, 64)         16448     ['depthwise_conv2d_4[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 125, 125, 128)        32896     ['depthwise_conv2d_5[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 125, 125, 32)         8224      ['average_pooling2d_2[0][0]']
#
#  concatenate_2 (Concatenate  (None, 125, 125, 288)        0         ['conv2d_10[0][0]',
#  )                                                                   'conv2d_11[0][0]',
#                                                                      'conv2d_12[0][0]',
#                                                                      'conv2d_13[0][0]']
#
#  depthwise_conv2d_6 (Depthw  (None, 125, 125, 288)        2880      ['concatenate_2[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_7 (Depthw  (None, 125, 125, 288)        7488      ['concatenate_2[0][0]']
#  iseConv2D)
#
#  average_pooling2d_3 (Avera  (None, 125, 125, 288)        0         ['concatenate_2[0][0]']
#  gePooling2D)
#
#  conv2d_14 (Conv2D)          (None, 125, 125, 64)         18496     ['concatenate_2[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 125, 125, 64)         18496     ['depthwise_conv2d_6[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 125, 125, 128)        36992     ['depthwise_conv2d_7[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 125, 125, 32)         9248      ['average_pooling2d_3[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 125, 125, 288)        74016     ['activation[0][0]']
#
#  concatenate_3 (Concatenate  (None, 125, 125, 288)        0         ['conv2d_14[0][0]',
#  )                                                                   'conv2d_15[0][0]',
#                                                                      'conv2d_16[0][0]',
#                                                                      'conv2d_17[0][0]']
#
#  add_1 (Add)                 (None, 125, 125, 288)        0         ['conv2d_18[0][0]',
#                                                                      'concatenate_3[0][0]']
#
#  activation_1 (Activation)   (None, 125, 125, 288)        0         ['add_1[0][0]']
#
#  average_pooling2d_4 (Avera  (None, 31, 31, 288)          0         ['activation_1[0][0]']
#  gePooling2D)
#
#  flatten (Flatten)           (None, 276768)               0         ['average_pooling2d_4[0][0]']
#
#  dense (Dense)               (None, 6)                    1660614   ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 2026918 (7.73 MB)
# Trainable params: 2026918 (7.73 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
import time
# Record the start time of training
start_time = time.time()

# %%
# Train the model
epochs = 50

#Callback to save the best model
callbacks_list = [
    keras.callbacks.ModelCheckpoint(
        filepath='Depth_Incep_Res_model_50epochs.h5',
        monitor='val_loss', save_best_only=True, verbose=1)
]

#Training
history_1 = model.fit(
        train_generator,
        steps_per_epoch=nb_train_samples // BATCH_SIZE,
        epochs=epochs,
        callbacks = callbacks_list,
        validation_data=validation_generator,
        verbose = 1,
        validation_steps=nb_validation_samples // BATCH_SIZE)
# Out:
# Epoch 1/50
# 2024-04-16 19:25:27.150907: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2024-04-16 19:25:32.932202: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-04-16 19:25:33.184114: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1c3806a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-04-16 19:25:33.184181: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A4000, Compute Capability 8.6
# 2024-04-16 19:25:33.359725: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-04-16 19:25:34.052167: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 105/105 [==============================] - ETA: 0s - loss: 1.6672 - accuracy: 0.4024
# Epoch 1: val_loss improved from inf to 1.16195, saving model to Depth_Incep_Res_model_50epochs.h5
# /environment/miniconda3/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 105/105 [==============================] - 71s 447ms/step - loss: 1.6672 - accuracy: 0.4024 - val_loss: 1.1619 - val_accuracy: 0.5697
# Epoch 2/50
# 105/105 [==============================] - ETA: 0s - loss: 1.0330 - accuracy: 0.6054
# Epoch 2: val_loss did not improve from 1.16195
# 105/105 [==============================] - 47s 445ms/step - loss: 1.0330 - accuracy: 0.6054 - val_loss: 1.3038 - val_accuracy: 0.5264
# Epoch 3/50
# 105/105 [==============================] - ETA: 0s - loss: 0.9196 - accuracy: 0.6637
# Epoch 3: val_loss improved from 1.16195 to 1.14260, saving model to Depth_Incep_Res_model_50epochs.h5
# 105/105 [==============================] - 46s 439ms/step - loss: 0.9196 - accuracy: 0.6637 - val_loss: 1.1426 - val_accuracy: 0.6394
# Epoch 4/50
# 105/105 [==============================] - ETA: 0s - loss: 0.8483 - accuracy: 0.7077
# Epoch 4: val_loss improved from 1.14260 to 1.02014, saving model to Depth_Incep_Res_model_50epochs.h5
# 105/105 [==============================] - 49s 460ms/step - loss: 0.8483 - accuracy: 0.7077 - val_loss: 1.0201 - val_accuracy: 0.6418
# Epoch 5/50
# 105/105 [==============================] - ETA: 0s - loss: 0.7618 - accuracy: 0.7345
# Epoch 5: val_loss improved from 1.02014 to 0.92910, saving model to Depth_Incep_Res_model_50epochs.h5
# 105/105 [==============================] - 47s 441ms/step - loss: 0.7618 - accuracy: 0.7345 - val_loss: 0.9291 - val_accuracy: 0.6995
# Epoch 6/50
# 105/105 [==============================] - ETA: 0s - loss: 0.7747 - accuracy: 0.7024
# Epoch 6: val_loss improved from 0.92910 to 0.81979, saving model to Depth_Incep_Res_model_50epochs.h5
# 105/105 [==============================] - 47s 445ms/step - loss: 0.7747 - accuracy: 0.7024 - val_loss: 0.8198 - val_accuracy: 0.6995
# Epoch 7/50
# 105/105 [==============================] - ETA: 0s - loss: 0.6400 - accuracy: 0.7661
# Epoch 7: val_loss improved from 0.81979 to 0.74999, saving model to Depth_Incep_Res_model_50epochs.h5
# 105/105 [==============================] - 49s 466ms/step - loss: 0.6400 - accuracy: 0.7661 - val_loss: 0.7500 - val_accuracy: 0.7260
# Epoch 8/50
# 105/105 [==============================] - ETA: 0s - loss: 0.6462 - accuracy: 0.7714
# Epoch 8: val_loss did not improve from 0.74999
# 105/105 [==============================] - 48s 455ms/step - loss: 0.6462 - accuracy: 0.7714 - val_loss: 0.7796 - val_accuracy: 0.7139
# Epoch 9/50
# 105/105 [==============================] - ETA: 0s - loss: 0.6871 - accuracy: 0.7446
# Epoch 9: val_loss improved from 0.74999 to 0.73521, saving model to Depth_Incep_Res_model_50epochs.h5
# 105/105 [==============================] - 46s 440ms/step - loss: 0.6871 - accuracy: 0.7446 - val_loss: 0.7352 - val_accuracy: 0.7476
# Epoch 10/50
# 105/105 [==============================] - ETA: 0s - loss: 0.5644 - accuracy: 0.7976
# Epoch 10: val_loss did not improve from 0.73521
# 105/105 [==============================] - 48s 451ms/step - loss: 0.5644 - accuracy: 0.7976 - val_loss: 0.7902 - val_accuracy: 0.7308
# Epoch 11/50
# 105/105 [==============================] - ETA: 0s - loss: 0.5329 - accuracy: 0.8060
# Epoch 11: val_loss did not improve from 0.73521
# 105/105 [==============================] - 47s 448ms/step - loss: 0.5329 - accuracy: 0.8060 - val_loss: 0.7613 - val_accuracy: 0.7452
# Epoch 12/50
# 105/105 [==============================] - ETA: 0s - loss: 0.4722 - accuracy: 0.8262
# Epoch 12: val_loss improved from 0.73521 to 0.63725, saving model to Depth_Incep_Res_model_50epochs.h5
# 105/105 [==============================] - 49s 466ms/step - loss: 0.4722 - accuracy: 0.8262 - val_loss: 0.6373 - val_accuracy: 0.7788
# Epoch 13/50
# 105/105 [==============================] - ETA: 0s - loss: 0.4655 - accuracy: 0.8339
# Epoch 13: val_loss did not improve from 0.63725
# 105/105 [==============================] - 48s 456ms/step - loss: 0.4655 - accuracy: 0.8339 - val_loss: 1.0609 - val_accuracy: 0.6274
# Epoch 14/50
# 105/105 [==============================] - ETA: 0s - loss: 0.4508 - accuracy: 0.8304
# Epoch 14: val_loss improved from 0.63725 to 0.61123, saving model to Depth_Incep_Res_model_50epochs.h5
# 105/105 [==============================] - 47s 449ms/step - loss: 0.4508 - accuracy: 0.8304 - val_loss: 0.6112 - val_accuracy: 0.7885
# Epoch 15/50
# 105/105 [==============================] - ETA: 0s - loss: 0.4515 - accuracy: 0.8387
# Epoch 15: val_loss did not improve from 0.61123
# 105/105 [==============================] - 47s 441ms/step - loss: 0.4515 - accuracy: 0.8387 - val_loss: 0.6379 - val_accuracy: 0.7596
# Epoch 16/50
# 105/105 [==============================] - ETA: 0s - loss: 0.5396 - accuracy: 0.8095
# Epoch 16: val_loss did not improve from 0.61123
# 105/105 [==============================] - 48s 452ms/step - loss: 0.5396 - accuracy: 0.8095 - val_loss: 0.8860 - val_accuracy: 0.6923
# Epoch 17/50
# 105/105 [==============================] - ETA: 0s - loss: 0.5456 - accuracy: 0.8125
# Epoch 17: val_loss did not improve from 0.61123
# 105/105 [==============================] - 47s 442ms/step - loss: 0.5456 - accuracy: 0.8125 - val_loss: 0.7165 - val_accuracy: 0.7524
# Epoch 18/50
# 105/105 [==============================] - ETA: 0s - loss: 0.4315 - accuracy: 0.8440
# Epoch 18: val_loss improved from 0.61123 to 0.58923, saving model to Depth_Incep_Res_model_50epochs.h5
# 105/105 [==============================] - 48s 454ms/step - loss: 0.4315 - accuracy: 0.8440 - val_loss: 0.5892 - val_accuracy: 0.8029
# Epoch 19/50
# 105/105 [==============================] - ETA: 0s - loss: 0.4249 - accuracy: 0.8554
# Epoch 19: val_loss did not improve from 0.58923
# 105/105 [==============================] - 48s 459ms/step - loss: 0.4249 - accuracy: 0.8554 - val_loss: 0.6666 - val_accuracy: 0.7764
# Epoch 20/50
# 105/105 [==============================] - ETA: 0s - loss: 0.4429 - accuracy: 0.8494
# Epoch 20: val_loss did not improve from 0.58923
# 105/105 [==============================] - 47s 446ms/step - loss: 0.4429 - accuracy: 0.8494 - val_loss: 0.6580 - val_accuracy: 0.7788
# Epoch 21/50
# 105/105 [==============================] - ETA: 0s - loss: 0.4286 - accuracy: 0.8345
# Epoch 21: val_loss did not improve from 0.58923
# 105/105 [==============================] - 47s 446ms/step - loss: 0.4286 - accuracy: 0.8345 - val_loss: 0.6305 - val_accuracy: 0.7909
# Epoch 22/50
# 105/105 [==============================] - ETA: 0s - loss: 0.4028 - accuracy: 0.8554
# Epoch 22: val_loss did not improve from 0.58923
# 105/105 [==============================] - 47s 443ms/step - loss: 0.4028 - accuracy: 0.8554 - val_loss: 0.6755 - val_accuracy: 0.7620
# Epoch 23/50
# 105/105 [==============================] - ETA: 0s - loss: 0.3954 - accuracy: 0.8571
# Epoch 23: val_loss did not improve from 0.58923
# 105/105 [==============================] - 47s 447ms/step - loss: 0.3954 - accuracy: 0.8571 - val_loss: 0.7011 - val_accuracy: 0.7668
# Epoch 24/50
# 105/105 [==============================] - ETA: 0s - loss: 0.4042 - accuracy: 0.8500
# Epoch 24: val_loss improved from 0.58923 to 0.53362, saving model to Depth_Incep_Res_model_50epochs.h5
# 105/105 [==============================] - 48s 452ms/step - loss: 0.4042 - accuracy: 0.8500 - val_loss: 0.5336 - val_accuracy: 0.8053
# Epoch 25/50
# 105/105 [==============================] - ETA: 0s - loss: 0.3548 - accuracy: 0.8673
# Epoch 25: val_loss did not improve from 0.53362
# 105/105 [==============================] - 47s 447ms/step - loss: 0.3548 - accuracy: 0.8673 - val_loss: 0.6355 - val_accuracy: 0.8245
# Epoch 26/50
# 105/105 [==============================] - ETA: 0s - loss: 0.3674 - accuracy: 0.8667
# Epoch 26: val_loss did not improve from 0.53362
# 105/105 [==============================] - 49s 461ms/step - loss: 0.3674 - accuracy: 0.8667 - val_loss: 0.5936 - val_accuracy: 0.8029
# Epoch 27/50
# 105/105 [==============================] - ETA: 0s - loss: 0.3018 - accuracy: 0.8917
# Epoch 27: val_loss improved from 0.53362 to 0.48450, saving model to Depth_Incep_Res_model_50epochs.h5
# 105/105 [==============================] - 49s 464ms/step - loss: 0.3018 - accuracy: 0.8917 - val_loss: 0.4845 - val_accuracy: 0.8317
# Epoch 28/50
# 105/105 [==============================] - ETA: 0s - loss: 0.3812 - accuracy: 0.8560
# Epoch 28: val_loss did not improve from 0.48450
# 105/105 [==============================] - 49s 463ms/step - loss: 0.3812 - accuracy: 0.8560 - val_loss: 0.7150 - val_accuracy: 0.7548
# Epoch 29/50
# 105/105 [==============================] - ETA: 0s - loss: 0.3327 - accuracy: 0.8839
# Epoch 29: val_loss did not improve from 0.48450
# 105/105 [==============================] - 49s 468ms/step - loss: 0.3327 - accuracy: 0.8839 - val_loss: 0.4948 - val_accuracy: 0.8269
# Epoch 30/50
# 105/105 [==============================] - ETA: 0s - loss: 0.3146 - accuracy: 0.8923
# Epoch 30: val_loss improved from 0.48450 to 0.48027, saving model to Depth_Incep_Res_model_50epochs.h5
# 105/105 [==============================] - 50s 478ms/step - loss: 0.3146 - accuracy: 0.8923 - val_loss: 0.4803 - val_accuracy: 0.8510
# Epoch 31/50
# 105/105 [==============================] - ETA: 0s - loss: 0.2914 - accuracy: 0.8994
# Epoch 31: val_loss did not improve from 0.48027
# 105/105 [==============================] - 48s 450ms/step - loss: 0.2914 - accuracy: 0.8994 - val_loss: 0.5733 - val_accuracy: 0.8101
# Epoch 32/50
# 105/105 [==============================] - ETA: 0s - loss: 0.3215 - accuracy: 0.8780
# Epoch 32: val_loss did not improve from 0.48027
# 105/105 [==============================] - 50s 469ms/step - loss: 0.3215 - accuracy: 0.8780 - val_loss: 0.4874 - val_accuracy: 0.8365
# Epoch 33/50
# 105/105 [==============================] - ETA: 0s - loss: 0.3006 - accuracy: 0.8976
# Epoch 33: val_loss did not improve from 0.48027
# 105/105 [==============================] - 46s 436ms/step - loss: 0.3006 - accuracy: 0.8976 - val_loss: 0.8171 - val_accuracy: 0.7500
# Epoch 34/50
# 105/105 [==============================] - ETA: 0s - loss: 0.2941 - accuracy: 0.9000
# Epoch 34: val_loss did not improve from 0.48027
# 105/105 [==============================] - 47s 445ms/step - loss: 0.2941 - accuracy: 0.9000 - val_loss: 0.6902 - val_accuracy: 0.8149
# Epoch 35/50
# 105/105 [==============================] - ETA: 0s - loss: 0.2628 - accuracy: 0.9107
# Epoch 35: val_loss improved from 0.48027 to 0.46810, saving model to Depth_Incep_Res_model_50epochs.h5
# 105/105 [==============================] - 48s 458ms/step - loss: 0.2628 - accuracy: 0.9107 - val_loss: 0.4681 - val_accuracy: 0.8510
# Epoch 36/50
# 105/105 [==============================] - ETA: 0s - loss: 0.3695 - accuracy: 0.8667
# Epoch 36: val_loss did not improve from 0.46810
# 105/105 [==============================] - 47s 450ms/step - loss: 0.3695 - accuracy: 0.8667 - val_loss: 0.5904 - val_accuracy: 0.8005
# Epoch 37/50
# 105/105 [==============================] - ETA: 0s - loss: 0.2563 - accuracy: 0.9071
# Epoch 37: val_loss did not improve from 0.46810
# 105/105 [==============================] - 47s 445ms/step - loss: 0.2563 - accuracy: 0.9071 - val_loss: 0.5127 - val_accuracy: 0.8438
# Epoch 38/50
# 105/105 [==============================] - ETA: 0s - loss: 0.2762 - accuracy: 0.9012
# Epoch 38: val_loss did not improve from 0.46810
# 105/105 [==============================] - 47s 449ms/step - loss: 0.2762 - accuracy: 0.9012 - val_loss: 0.7323 - val_accuracy: 0.8365
# Epoch 39/50
# 105/105 [==============================] - ETA: 0s - loss: 0.2657 - accuracy: 0.9036
# Epoch 39: val_loss did not improve from 0.46810
# 105/105 [==============================] - 49s 465ms/step - loss: 0.2657 - accuracy: 0.9036 - val_loss: 0.5094 - val_accuracy: 0.8197
# Epoch 40/50
# 105/105 [==============================] - ETA: 0s - loss: 0.2909 - accuracy: 0.8976
# Epoch 40: val_loss did not improve from 0.46810
# 105/105 [==============================] - 48s 456ms/step - loss: 0.2909 - accuracy: 0.8976 - val_loss: 0.5756 - val_accuracy: 0.8149
# Epoch 41/50
# 105/105 [==============================] - ETA: 0s - loss: 0.2817 - accuracy: 0.8964
# Epoch 41: val_loss did not improve from 0.46810
# 105/105 [==============================] - 47s 445ms/step - loss: 0.2817 - accuracy: 0.8964 - val_loss: 0.6413 - val_accuracy: 0.7500
# Epoch 42/50
# 105/105 [==============================] - ETA: 0s - loss: 0.3197 - accuracy: 0.8863
# Epoch 42: val_loss did not improve from 0.46810
# 105/105 [==============================] - 49s 463ms/step - loss: 0.3197 - accuracy: 0.8863 - val_loss: 0.5367 - val_accuracy: 0.8341
# Epoch 43/50
# 105/105 [==============================] - ETA: 0s - loss: 0.2541 - accuracy: 0.9101
# Epoch 43: val_loss did not improve from 0.46810
# 105/105 [==============================] - 48s 453ms/step - loss: 0.2541 - accuracy: 0.9101 - val_loss: 0.5600 - val_accuracy: 0.8245
# Epoch 44/50
# 105/105 [==============================] - ETA: 0s - loss: 0.2882 - accuracy: 0.9030
# Epoch 44: val_loss did not improve from 0.46810
# 105/105 [==============================] - 46s 435ms/step - loss: 0.2882 - accuracy: 0.9030 - val_loss: 0.5627 - val_accuracy: 0.8317
# Epoch 45/50
# 105/105 [==============================] - ETA: 0s - loss: 0.2727 - accuracy: 0.9030
# Epoch 45: val_loss did not improve from 0.46810
# 105/105 [==============================] - 48s 452ms/step - loss: 0.2727 - accuracy: 0.9030 - val_loss: 0.6427 - val_accuracy: 0.8317
# Epoch 46/50
# 105/105 [==============================] - ETA: 0s - loss: 0.3369 - accuracy: 0.8869
# Epoch 46: val_loss did not improve from 0.46810
# 105/105 [==============================] - 48s 455ms/step - loss: 0.3369 - accuracy: 0.8869 - val_loss: 0.6602 - val_accuracy: 0.7788
# Epoch 47/50
# 105/105 [==============================] - ETA: 0s - loss: 0.2832 - accuracy: 0.8994
# Epoch 47: val_loss did not improve from 0.46810
# 105/105 [==============================] - 49s 464ms/step - loss: 0.2832 - accuracy: 0.8994 - val_loss: 0.8763 - val_accuracy: 0.8053
# Epoch 48/50
# 105/105 [==============================] - ETA: 0s - loss: 0.4422 - accuracy: 0.8589
# Epoch 48: val_loss did not improve from 0.46810
# 105/105 [==============================] - 48s 450ms/step - loss: 0.4422 - accuracy: 0.8589 - val_loss: 0.5261 - val_accuracy: 0.8341
# Epoch 49/50
# 105/105 [==============================] - ETA: 0s - loss: 0.2977 - accuracy: 0.8976
# Epoch 49: val_loss improved from 0.46810 to 0.46157, saving model to Depth_Incep_Res_model_50epochs.h5
# 105/105 [==============================] - 48s 458ms/step - loss: 0.2977 - accuracy: 0.8976 - val_loss: 0.4616 - val_accuracy: 0.8317
# Epoch 50/50
# 105/105 [==============================] - ETA: 0s - loss: 0.2863 - accuracy: 0.9054
# Epoch 50: val_loss did not improve from 0.46157
# 105/105 [==============================] - 49s 463ms/step - loss: 0.2863 - accuracy: 0.9054 - val_loss: 0.4989 - val_accuracy: 0.8462

# %%
# Record the training end time
end_time = time.time()

# %%
training_time = end_time - start_time
print(f"Training time: {training_time} seconds")
# Out:
# Training time: 2698.6036858558655 seconds

# %%
pd.DataFrame(history_1.history)
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   1.667233  0.402381  1.161947      0.569712
# 1   1.032977  0.605357  1.303842      0.526442
# 2   0.919635  0.663690  1.142602      0.639423
# 3   0.848275  0.707738  1.020140      0.641827
# 4   0.761796  0.734524  0.929101      0.699519
# 5   0.774654  0.702381  0.819787      0.699519
# 6   0.640025  0.766071  0.749990      0.725962
# 7   0.646164  0.771429  0.779648      0.713942
# 8   0.687073  0.744643  0.735206      0.747596
# 9   0.564406  0.797619  0.790168      0.730769
# 10  0.532907  0.805952  0.761297      0.745192
# 11  0.472209  0.826190  0.637254      0.778846
# 12  0.465479  0.833929  1.060940      0.627404
# 13  0.450830  0.830357  0.611232      0.788462
# 14  0.451535  0.838690  0.637940      0.759615
# 15  0.539577  0.809524  0.886030      0.692308
# 16  0.545582  0.812500  0.716470      0.752404
# 17  0.431525  0.844048  0.589232      0.802885
# 18  0.424875  0.855357  0.666646      0.776442
# 19  0.442881  0.849405  0.657974      0.778846
# 20  0.428584  0.834524  0.630498      0.790865
# 21  0.402768  0.855357  0.675451      0.762019
# 22  0.395399  0.857143  0.701081      0.766827
# 23  0.404250  0.850000  0.533618      0.805288
# 24  0.354844  0.867262  0.635455      0.824519
# 25  0.367403  0.866667  0.593557      0.802885
# 26  0.301775  0.891667  0.484502      0.831731
# 27  0.381164  0.855952  0.715037      0.754808
# 28  0.332697  0.883929  0.494807      0.826923
# 29  0.314638  0.892262  0.480270      0.850962
# 30  0.291382  0.899405  0.573251      0.810096
# 31  0.321546  0.877976  0.487377      0.836538
# 32  0.300579  0.897619  0.817125      0.750000
# 33  0.294093  0.900000  0.690217      0.814904
# 34  0.262846  0.910714  0.468104      0.850962
# 35  0.369547  0.866667  0.590442      0.800481
# 36  0.256287  0.907143  0.512721      0.843750
# 37  0.276162  0.901190  0.732332      0.836538
# 38  0.265732  0.903571  0.509363      0.819712
# 39  0.290939  0.897619  0.575579      0.814904
# 40  0.281655  0.896429  0.641272      0.750000
# 41  0.319687  0.886310  0.536666      0.834135
# 42  0.254054  0.910119  0.559956      0.824519
# 43  0.288154  0.902976  0.562704      0.831731
# 44  0.272687  0.902976  0.642725      0.831731
# 45  0.336853  0.886905  0.660229      0.778846
# 46  0.283249  0.899405  0.876267      0.805288
# 47  0.442247  0.858929  0.526144      0.834135
# 48  0.297716  0.897619  0.461569      0.831731
# 49  0.286320  0.905357  0.498864      0.846154

# %%
import joblib

# joblib.dump(history_1.history,'Depthwise_Inception_ResNet with DA_50epochs.pkl')
history_CNN1 = joblib.load('Depthwise_Inception_ResNet with DA_50epochs.pkl')

# %%
def plot_performance(model_name, acc, val_acc, loss, val_loss):
  plt.figure(figsize=(10,5))
  plt.subplot(1,2,1)
  plt.plot(loss)
  plt.plot(val_loss)
  plt.title('{} : Loss'.format(model_name), fontsize=12, fontweight='bold')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['train', 'test'], loc='upper right')

  plt.subplot(1,2,2)
  plt.plot(acc)
  plt.plot(val_acc)
  plt.title('{} : Accuracy'.format(model_name), fontsize=12, fontweight='bold')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['train', 'test'], loc='lower right')

  plt.tight_layout()

# %%
plot_performance(model_name='DepthWiseInceptionResNet',
                acc=history_CNN1['accuracy'], 
                 val_acc=history_CNN1['val_accuracy'],
                 loss=history_CNN1['loss'], 
                 val_loss=history_CNN1['val_loss'])

# %%
# Load the best saved model
from keras.models import load_model

model = load_model('Depth_Incep_Res_model_50epochs.h5')
score = model.evaluate(validation_generator)
val_loss.append(score[0])
val_accuracy.append(score[1])
print('\nVal loss:', score[0])
print('Val accuracy:', score[1])

score = model.evaluate(test_generator)
print('\nTest loss:', score[0])
print('Test accuracy:', score[1])

test_loss.append(score[0])
test_accuracy.append(score[1])
# Out:
# 27/27 [==============================] - 10s 343ms/step - loss: 0.4867 - accuracy: 0.8214
#
# Val loss: 0.48666444420814514
# Val accuracy: 0.8214285969734192
# 33/33 [==============================] - 13s 375ms/step - loss: 0.3249 - accuracy: 0.8920
#
# Test loss: 0.32494062185287476
# Test accuracy: 0.8920454382896423

# %%
import itertools

#Plot the confusion matrix. Set Normalize = True/False
def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

#Confution Matrix and Classification Report
Y_pred = model.predict(test_generator)#, nb_test_samples // BATCH_SIZE, workers=1)
y_pred = np.argmax(Y_pred, axis=1)
target_names = classes

#Confution Matrix
cm = confusion_matrix(test_generator.classes, y_pred)
plot_confusion_matrix(cm, target_names, normalize=False, title='Confusion Matrix')
print('Classification Report')
print(classification_report(test_generator.classes, y_pred, target_names=target_names, zero_division=1))
# Out:
# 33/33 [==============================] - 12s 359ms/step
# Classification Report
#                        precision    recall  f1-score   support
#
# bacterial_leaf_blight       0.79      0.98      0.87        88
#            brown_spot       0.86      0.73      0.79        88
#               healthy       0.91      0.92      0.92        88
#            leaf_blast       0.81      0.66      0.73        88
#            leaf_scald       0.96      1.00      0.98        88
#     narrow_brown_spot       0.91      0.95      0.93        88
#
#              accuracy                           0.87       528
#             macro avg       0.87      0.87      0.87       528
#          weighted avg       0.87      0.87      0.87       528

# %%
# Precision-Recall Curve for each class
from sklearn.metrics import precision_recall_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt

n_classes = len(classes)
y_true_bin = label_binarize(test_generator.classes, classes=list(range(n_classes)))
precision = dict()
recall = dict()
auc_score = dict()

plt.figure(figsize=(10, 8))

for i in range(n_classes):
    precision[i], recall[i], _ = precision_recall_curve(y_true_bin[:, i], Y_pred[:, i])
    auc_score[i] = auc(recall[i], precision[i])
    
    plt.plot(recall[i], precision[i], lw=2, label=f'Class {i} (AUC = {auc_score[i]:.2f})')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve for each class')
plt.legend(loc="best")
plt.show()

# %%
#Generate predictions for the test dataset
y_pred = model.predict(test_generator)
y_pred_labels = (y_pred>0.5).astype(int)

#Get the true labels from thee test generator
y_true = test_generator.classes
# Out:
# 33/33 [==============================] - 12s 347ms/step

# %%
# Compute ROC curve
from sklearn.metrics import roc_curve, auc

#Get the true labels from thee test generator
# y_true = test_generator.classes
y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))

# Initialize arrays to store fpr, tpr, and auc for each class
fpr = dict()
tpr = dict()
roc_auc = dict()


# Compute ROC curve and ROC area for each class
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve for each class
plt.figure(figsize=(10, 6))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], lw=2, label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
# Initialize the list of Sensitivity and Specificity for each class
sensitivity_list = []
specificity_list = []

# The Sensitivity and Specificity of each class were calculated
for i in range(len(cm)):
    tp = cm[i, i]  # True Positive
    fn = np.sum(cm[i, :]) - tp  # False Negative
    fp = np.sum(cm[:, i]) - tp  # False Positive
    tn = np.sum(cm) - (tp + fn + fp)  # True Negative
    
    sensitivity = tp / (tp + fn + 1e-10)  # Add a small number to avoid dividing by zero
    specificity = tn / (tn + fp + 1e-10)
    
    sensitivity_list.append(sensitivity)
    specificity_list.append(specificity)

# Plot Sensitivity and Specificity for each class
plt.figure(figsize=(10, 6))
plt.plot(range(len(sensitivity_list)), sensitivity_list, marker='o', label='Sensitivity')
plt.plot(range(len(specificity_list)), specificity_list, marker='s', label='Specificity')
plt.xlabel('Class')
plt.ylabel('Value')
plt.title('Sensitivity and Specificity for each class')
plt.legend()

# Add numeric labels
for i, (sensitivity, specificity) in enumerate(zip(sensitivity_list, specificity_list)):
    plt.text(i, sensitivity, f'{sensitivity:.2f}', ha='right', va='bottom')
    plt.text(i, specificity, f'{specificity:.2f}', ha='right', va='bottom')

plt.show()

# %%
print(sensitivity_list)
print(specificity_list)
# Out:
# [0.9772727272716167, 0.7272727272719008, 0.9204545454534995, 0.6590909090901601, 0.9999999999988636, 0.9545454545443698]
# [0.9477272727270574, 0.9772727272725052, 0.9818181818179587, 0.9681818181815982, 0.9909090909088657, 0.9818181818179587]

# %%
# Evaluate the performance of the model
evaluate = model.evaluate(
    test_generator, 
    steps = test_generator.n // BATCH_SIZE, 
    verbose = 1
)

print('Accuracy Test : {}'.format(evaluate[1]))
# Out:
# 33/33 [==============================] - 13s 374ms/step - loss: 0.3407 - accuracy: 0.8807
# Accuracy Test : 0.8806818127632141

# %%
from keras import backend as K
import gc

K.clear_session()
gc.collect()

del model

# %%
#You need to install numba using 'pip install numba'

from numba import cuda

cuda.select_device(0)
cuda.close()
